# %%
import numpy as np
import matplotlib.pyplot as plt
import Ohm
from RLCFit import *

# %% [markdown]
# In the space below, include all your data.
# - Each individual list is a data point, for example ``[1, 0.1]`` would be a data point $1 \pm 0.1$.
# - The quotes at the end of each is for the units, for example ``"mV"`` or ``"uA"`` for millivolts and microamps. Whatever are the units of the data.
# - ``R_best_Ohms`` should be the best value of the resistance in Ohms (both the value and the uncertainty)
# - ``L_guess_mH`` should be an estimate of L, in mH
# - ``C_guess_uF`` should be an estimate of C, in $\mu$F
# - ``result_filename`` will be the name of the file created with the results. You should choose a unique name so you know your data file.

# %%
t = [[, ],
     [, ],
     [, ],
     [, ],
     [, ],
     [, ],
     [, ],
     ""]

V = [[, ],
     [, ],
     [, ],
     [, ],
     [, ],
     [, ],
     [, ],
     ""]

R_best_Ohms = [ , ]

L_guess_mH = 
C_guess_uF = 

result_filename = ""

# %%
data = make_data_dictionary(t, V, [R_best_Ohms, L_guess_mH, C_guess_uF])

# %% [markdown]
# The above graph should look approximately right. If not, double check the data points and re-examine the guess for the resistance.
#
# Do not move on until the graph looks approximately right.
#
# The next cell will compute the results and create the result of the best fit and create a file.

# %%
best_fit(data, result_filename)
